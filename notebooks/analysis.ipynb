# %%
import sys

sys.path.append('..')

from src.data_read import load_data
from src.visualize import plot_acc_exercise, plot_gyro_exercise, plot_mag_exercise


df = load_data()
print(df.head())
# Out:
#    time index     acc_x     acc_y     acc_z     gyr_x     gyr_y     gyr_z  \
# 0           1 -9.685645 -1.645149  0.505022 -0.020696  0.009202 -0.008566
# 1           2 -9.648184 -1.645353  0.513125 -0.008165 -0.001407 -0.003256
# 2           3 -9.700570 -1.615223  0.512321 -0.004447  0.011059 -0.008589
# 3           4 -9.685627 -1.630183  0.497591 -0.026110  0.009183 -0.008554
# 4           5 -9.655697 -1.630194  0.460742 -0.008109  0.001231 -0.005950
#
#       mag_x     mag_y     mag_z  time subject exercise unit
# 0  0.589728  0.453403 -0.075234  0.00      s1       e1   u1
# 1  0.587024  0.453644 -0.075593  0.04      s1       e1   u1
# 2  0.589691  0.454598 -0.075525  0.08      s1       e1   u1
# 3  0.589240  0.452864 -0.074705  0.12      s1       e1   u1
# 4  0.589647  0.452882 -0.076429  0.16      s1       e1   u1

# %%
plot_acc_exercise(df, "e1", subject="s1", unit="u1")
plot_acc_exercise(df, "e1", subject="s1", unit="u2")
plot_acc_exercise(df, "e1", subject="s1", unit="u3")
plot_acc_exercise(df, "e1", subject="s1", unit="u4")
plot_acc_exercise(df, "e1", subject="s1", unit="u5")

# %%
plot_gyro_exercise(df, "e1", subject="s1", unit="u1")
plot_gyro_exercise(df, "e1", subject="s1", unit="u2")
plot_gyro_exercise(df, "e1", subject="s1", unit="u3")
plot_gyro_exercise(df, "e1", subject="s1", unit="u4")
plot_gyro_exercise(df, "e1", subject="s1", unit="u5")

# %%
plot_mag_exercise(df, "e1", subject="s1", unit="u1")
plot_mag_exercise(df, "e1", subject="s1", unit="u2")
plot_mag_exercise(df, "e1", subject="s1", unit="u3")
plot_mag_exercise(df, "e1", subject="s1", unit="u4")
plot_mag_exercise(df, "e1", subject="s1", unit="u5")
